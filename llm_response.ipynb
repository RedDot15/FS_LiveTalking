# %%
import os
from dotenv import load_dotenv

from openai import OpenAI
client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY") 
)

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {'role': 'system', 'content': 'You are a helpful assistant.'},
        {'role': 'user', 'content': 'Hello'}
    ],
    stream=True,
    stream_options={"include_usage": True}
)

# %%
results = []
for chunk in completion:
    results.append(chunk)

# %%
print(results)
# Out:
# [ChatCompletionChunk(id='chatcmpl-C2e27THuDRCkFovYTFXSOHmdbGTfW', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1754746579, model='gpt-4o-mini-2024-07-18', object='chat.completion.chunk', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=None, obfuscation='gKkMRavXU'), ChatCompletionChunk(id='chatcmpl-C2e27THuDRCkFovYTFXSOHmdbGTfW', choices=[Choice(delta=ChoiceDelta(content='Hello', function_call=None, refusal=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1754746579, model='gpt-4o-mini-2024-07-18', object='chat.completion.chunk', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=None, obfuscation='oOv7Nj'), ChatCompletionChunk(id='chatcmpl-C2e27THuDRCkFovYTFXSOHmdbGTfW', choices=[Choice(delta=ChoiceDelta(content='!', function_call=None, refusal=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1754746579, model='gpt-4o-mini-2024-07-18', object='chat.completion.chunk', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=None, obfuscation='zmewTSj8u5'), ChatCompletionChunk(id='chatcmpl-C2e27THuDRCkFovYTFXSOHmdbGTfW', choices=[Choice(delta=ChoiceDelta(content=' How', function_call=None, refusal=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1754746579, model='gpt-4o-mini-2024-07-18', object='chat.completion.chunk', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=None, obfuscation='aMv1dOf'), ChatCompletionChunk(id='chatcmpl-C2e27THuDRCkFovYTFXSOHmdbGTfW', choices=[Choice(delta=ChoiceDelta(content=' can', function_call=None, refusal=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1754746579, model='gpt-4o-mini-2024-07-18', object='chat.completion.chunk', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=None, obfuscation='Hq1H9Tc'), ChatCompletionChunk(id='chatcmpl-C2e27THuDRCkFovYTFXSOHmdbGTfW', choices=[Choice(delta=ChoiceDelta(content=' I', function_call=None, refusal=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1754746579, model='gpt-4o-mini-2024-07-18', object='chat.completion.chunk', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=None, obfuscation='0EtF4a5pG'), ChatCompletionChunk(id='chatcmpl-C2e27THuDRCkFovYTFXSOHmdbGTfW', choices=[Choice(delta=ChoiceDelta(content=' assist', function_call=None, refusal=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1754746579, model='gpt-4o-mini-2024-07-18', object='chat.completion.chunk', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=None, obfuscation='iwNe'), ChatCompletionChunk(id='chatcmpl-C2e27THuDRCkFovYTFXSOHmdbGTfW', choices=[Choice(delta=ChoiceDelta(content=' you', function_call=None, refusal=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1754746579, model='gpt-4o-mini-2024-07-18', object='chat.completion.chunk', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=None, obfuscation='2sZNVyU'), ChatCompletionChunk(id='chatcmpl-C2e27THuDRCkFovYTFXSOHmdbGTfW', choices=[Choice(delta=ChoiceDelta(content=' today', function_call=None, refusal=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1754746579, model='gpt-4o-mini-2024-07-18', object='chat.completion.chunk', service_tier='default', system_fingerprint='fp_34a54ae93c', usage=None, obfuscation='3lsFA'), ChatCompletionChunk(id='chatcmpl-C2e27THuDRCkFovYTFXSOHmdbGTfW', choices=[Choice(delta=ChoiceDelta(content='?', function_call=None, refusal=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1754746579, model='gpt-4o-mini-2024-07-18', object='chat.completion.chunk', service_tier='default', system_fingerprint='fp_34a54a ...

# %%
for chunk in results:
    choices = chunk.choices
    
    for choice in choices:
        print(choice.delta.content, end='')
# Out:
# Hello! How can I assist you today?None
